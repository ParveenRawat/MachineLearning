# %%
import pandas as pd
import seaborn as sns
from sklearn import linear_model

# %%
df = pd.read_csv("./Data/Premium.csv")
df
# Out:
#    age  height  weight  premium
# 0   25  162.56      70    18000
# 1   30  172.62      95    36000
# 2   35  167.16      78    39000
# 3   40     NaN     110    60000
# 4   45  157.00      85    70000

# %%
mean_height = df.height.mean()
mean_height
# Out:
# 164.835

# %%
df.height
# Out:
# 0    162.56
# 1    172.62
# 2    167.16
# 3       NaN
# 4    157.00
# Name: height, dtype: float64

# %%
df.height = df.height.fillna(mean_height)
df
# Out:
#    age   height  weight  premium
# 0   25  162.560      70    18000
# 1   30  172.620      95    36000
# 2   35  167.160      78    39000
# 3   40  164.835     110    60000
# 4   45  157.000      85    70000

# %%
df.columns
# Out:
# Index(['age', 'height', 'weight', 'premium'], dtype='object')

# %%
sns.lmplot(x = "age",y = "premium",data = df)

# %%
reg = linear_model.LinearRegression()
reg.fit(df[["age"]],df[["premium"]])
# Out:
# LinearRegression()

# %%
reg.predict([[18]])
# Out:
# /home/parveen/Parveen/work/notebooks/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[1080.]])

# %%
reg.coef_
# Out:
# array([[2560.]])

# %%
reg.intercept_
# Out:
# array([-45000.])
